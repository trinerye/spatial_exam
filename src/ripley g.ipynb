# %% [markdown]
# #  Ripley G function

# %%
# !pip install pandas matplotlib numpy pointpats
# Out:
# Requirement already satisfied: pandas in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: pointpats in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.8 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from pointpats) (1.12.0)
# Requirement already satisfied: libpysal>=4 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from pointpats) (4.10)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from libpysal>=4->pointpats) (4.12.3)
# Requirement already satisfied: geopandas>=0.10.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from libpysal>=4->pointpats) (0.14.4)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\albin\appdata\roaming\python\python311\site-packages (from libpysal>=4->pointpats) (4.2.1)
# Requirement already satisfied: requests>=2.27 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from libpysal>=4->pointpats) (2.31.0)
# Requirement already satisfied: shapely>=2.0.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from libpysal>=4->pointpats) (2.0.4)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from libpysal>=4->pointpats) (1.4.1.post1)
# Requirement already satisfied: six>=1.5 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.10->libpysal>=4->pointpats) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.10.0->libpysal>=4->pointpats) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.10.0->libpysal>=4->pointpats) (3.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->libpysal>=4->pointpats) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->libpysal>=4->pointpats) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->libpysal>=4->pointpats) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->libpysal>=4->pointpats) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.1->libpysal>=4->pointpats) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.1->libpysal>=4->pointpats) (3.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4->pointpats) (23.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4->pointpats) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4->pointpats) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4->pointpats) (0.7.2)
# Requirement already satisfied: colorama in c:\users\albin\appdata\local\programs\python\python311\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4->pointpats) (0.4.6)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from pointpats import distance_statistics

# %%
# Load your data
data_file = os.path.join('..', 'in', 'datacenters_usa_clean.csv')

#where to save data
out_path = os.path.join('..', 'out')

dc_df = pd.read_csv(data_file)

# %%
def remove_nan_rows(df, lat_column='latitude', lon_column='longitude'):
    """
    Remove rows with NaN values in specified latitude and longitude columns from a dataframe.
    
    Parameters:
    - df: pandas DataFrame
        The dataframe containing latitude and longitude columns.
    - lat_column: str, optional (default='latitude')
        Name of the latitude column.
    - lon_column: str, optional (default='longitude')
        Name of the longitude column.
    
    Returns:
    - df_cleaned: pandas DataFrame
        DataFrame with rows containing NaN values in latitude or longitude columns removed.
    """
    # Check for NaN values in specified columns
    nan_mask = df[[lat_column, lon_column]].isnull().any(axis=1)
    
    # Remove rows with NaN values
    df_cleaned = df[~nan_mask]
    
    return df_cleaned

# %%
dc_df = remove_nan_rows(dc_df)
# Out:
# 2526

# %% [markdown]
# ### Compute Ripley G
# Below we create a custom function to pass a dataframe into, along iwth the columns for latitude an longitude.
#
# The function extracts the coordinates from the lat & long columns, and using those data center coordinates, runs a specified amount of simulations, which is known as a "G_test". This means we run N amount of simulations, and
#
# We can also optionally specify how many simulations to run (default=9999 simulations. Took about 5 minutes to compute on own hardware). Decrease amount of simulations to speed up computation.

# %%
def compute_ripley_g(df, lat_column, long_column, detail=100, simulations=9999):
    # Extract coordinates from latitude and longitude columns
    coordinates = df[[lat_column, long_column]].values

    #perform a g_test on the extracted coordinates
    g_test = distance_statistics.g_test(
        coordinates, support=detail, keep_simulations=True, n_simulations=simulations
    )
    return g_test, coordinates

# %%
#compute a ripley g test, by performing 9999 simulations. 
g_test, coordinates = compute_ripley_g(dc_df, 'latitude', 'longitude', simulations=9999)

# %%
def plot_ripley(coordinates, test, type, xlim=False, save_filename=None):
    # Plotting
    f, ax = plt.subplots(1, 2, figsize=(9, 3), gridspec_kw=dict(width_ratios=(6, 3)))

    # Plot simulations with fine lines
    ax[0].plot(test.support, test.simulations.T, color="k", alpha=0.01)

    # Plot median of simulations
    ax[0].plot(test.support, np.median(test.simulations, axis=0), color="cyan", label="median simulation")

    # Plot observed pattern's F function
    ax[0].plot(test.support, test.statistic, label="observed", color="red")

    # Labeling and formatting
    ax[0].set_xlabel("Distance")
    ax[0].set_ylabel("% of nearest point in pattern\ndistances shorter")
    ax[0].legend()
    if xlim:
        ax[0].set_xlim(0, xlim)
    ax[0].set_title(f"Ripley's ${type}(d)$ function")

    # Plot the data points themselves
    #coordinates[:, 1] = longitude
    #coordinates[:, 0] = latitude
    #s = size of points
    ax[1].scatter(coordinates[:, 1], coordinates[:, 0], s=1)

    # Formatting the plot of the pattern
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_xticklabels([])
    ax[1].set_yticklabels([])
    ax[1].set_title("Pattern")

    # Adjust layout and display
    f.tight_layout()
    
    # Optionally save the plot
    if save_filename:
        plt.savefig(os.path.join(out_path, save_filename))
    
    plt.show()

# %%
plot_ripley(coordinates, g_test, 'G', xlim=2, save_filename='Ripley G plot.png')
